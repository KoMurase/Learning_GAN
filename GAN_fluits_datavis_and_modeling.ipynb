# %% [markdown]
# <a href="https://colab.research.google.com/github/KoMurase/Learning_GAN/blob/master/GAN_fluits_datavis_and_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip "/content/drive/My Drive/GAN/data/fluits/50721_94741_bundle_archive.zip" -d "/content/drive/My Drive/GAN/data/fluits"

# %%
import cv2
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline 

import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# #applenについての情報の記録

# %%
import pathlib
p_temp = pathlib.Path("/content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples")
apples_dataframe = pd.DataFrame(columns = ["filename", "Height", "Width"])

filenames = []
W=[]
H=[]
count_apples=0
for file in p_temp.iterdir():
  print(file)
  filenames.append(file)
  img=cv2.imread(str(file))
  h,w,c = img.shape
  H.append(h)
  W.append(w)
  count_apples+=1
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  plt.imshow(img)
  #if count_apples==5:
  #  break
print(count_apples)
# Out:
# /content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples/Screen Shot 2018-06-08 at 4.59.36 PM.png
# /content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples/Screen Shot 2018-06-08 at 4.59.44 PM.png
# /content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples/Screen Shot 2018-06-08 at 4.59.49 PM.png
# /content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples/Screen Shot 2018-06-08 at 4.59.57 PM.png
# /content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples/Screen Shot 2018-06-08 at 5.00.03 PM.png
# /content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples/Screen Shot 2018-06-08 at 5.00.12 PM.png
# /content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples/Screen Shot 2018-06-08 at 5.00.18 PM.png
# /content/drive/My Drive/GAN/data/fluits/original_data_set/freshapples/Screen Shot 2018-06-08 at 5.00.26 PM.png
# ...

# %%
apples_dataframe
# Out:
# Empty DataFrame
# Columns: [filename, Height, Width]
# Index: []

# %%
apples_dataframe["filename"] = filenames
apples_dataframe["Height"] = H
apples_dataframe["Width"] = W

# %%
apples_dataframe
# Out:
#                                               filename  Height  Width
# 0    /content/drive/My Drive/GAN/data/fluits/origin...     476    458
# 1    /content/drive/My Drive/GAN/data/fluits/origin...     386    470
# 2    /content/drive/My Drive/GAN/data/fluits/origin...     402    416
# 3    /content/drive/My Drive/GAN/data/fluits/origin...     452    436
# 4    /content/drive/My Drive/GAN/data/fluits/origin...     418    412
# ..                                                 ...     ...    ...
# 227  /content/drive/My Drive/GAN/data/fluits/origin...     342    376
# 228  /content/drive/My Drive/GAN/data/fluits/origin...     332    362
# 229  /content/drive/My Drive/GAN/data/fluits/origin...     362    410
# 230  /content/drive/My Drive/GAN/data/fluits/origin...     434    458
# 231  /content/drive/My Drive/GAN/data/fluits/origin...     402    374
#
# [232 rows x 3 columns]

# %%
apples_dataframe.shape
# Out:
# (232, 3)

# %%
# import useful tools
from glob import glob
from PIL import Image
import cv2

# %%
def plot_image_examples(df, rows=3, cols=3, title='Image examples'):
    fig, axs = plt.subplots(rows, cols, figsize=(10,10))
    for row in range(rows):
        for col in range(cols):
            idx = np.random.randint(len(df), size=1)[0]
            img_id = df.iloc[idx].filename
            
            #img = Image.open(TRAIN_DIR + img_id + '.png')
            img = Image.open(img_id)
            axs[row, col].imshow(img)
            
            #bboxes = get_all_bboxes(df, img_id)
            
            #for bbox in bboxes:
            #    rect = patches.Rectangle((bbox[0],bbox[1]),bbox[2],bbox[3],linewidth=1,edgecolor='r',facecolor='none')
            #    axs[row, col].add_patch(rect)
            
            #axs[row, col].axis('off')
            
    plt.suptitle(title)

# %%
plot_image_examples(apples_dataframe)
